# %% [markdown]
# Creating a Intrusion based detection system using the NSL KDD dataset.

# %% [markdown]
# Doing the same thing but building a Neural network model this time

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("KDDTrain+.txt")

# %%
columns = (['duration'
,'protocol_type'
,'service'
,'flag'
,'src_bytes'
,'dst_bytes'
,'land'
,'wrong_fragment'
,'urgent'
,'hot'
,'num_failed_logins'
,'logged_in'
,'num_compromised'
,'root_shell'
,'su_attempted'
,'num_root'
,'num_file_creations'
,'num_shells'
,'num_access_files'
,'num_outbound_cmds'
,'is_host_login'
,'is_guest_login'
,'count'
,'srv_count'
,'serror_rate'
,'srv_serror_rate'
,'rerror_rate'
,'srv_rerror_rate'
,'same_srv_rate'
,'diff_srv_rate'
,'srv_diff_host_rate'
,'dst_host_count'
,'dst_host_srv_count'
,'dst_host_same_srv_rate'
,'dst_host_diff_srv_rate'
,'dst_host_same_src_port_rate'
,'dst_host_srv_diff_host_rate'
,'dst_host_serror_rate'
,'dst_host_srv_serror_rate'
,'dst_host_rerror_rate'
,'dst_host_srv_rerror_rate'
,'attack'
,'level'])

df.columns = columns

# %%
attack_n = []
for i in df.attack:
    if i == 'normal':
        attack_n.append("normal")
    else:
        attack_n.append("intrusion")
df['attack'] = attack_n

# %%
y = df['attack'] 
y = y.apply(lambda x: 0 if x == 'normal' else 1)
print(y.unique())
# Out:
# [0 1]

# %%
features = ['protocol_type', 'service', 'flag', 'is_guest_login']
X = df[features]

# %%
X = pd.get_dummies(X, columns=['protocol_type', 'service', 'flag'])

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.1,
    random_state=42
)

# %%
print(y.unique())
# Out:
# [0 1]

# %% [markdown]
# Converting Labels to Numpy

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()


model.add(Dense(64, activation='relu', input_shape=(X_train.shape[1],)))

model.add(Dense(32, activation='relu'))

model.add(Dense(16, activation='relu'))

model.add(Dense(1, activation='sigmoid'))
# Out:
# C:\Users\sanja\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
model.summary()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_24 (Dense)                     │ (None, 64)                  │           5,504 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_25 (Dense)                     │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_26 (Dense)                     │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_27 (Dense)                     │ (None, 1)                   │              17 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 8,129 (31.75 KB)
#  Trainable params: 8,129 (31.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
X_train = np.array(X_train, dtype=np.float32)
X_test  = np.array(X_test, dtype=np.float32)

y_train = np.array(y_train, dtype=np.float32)
y_test  = np.array(y_test, dtype=np.float32)

# %%
history = model.fit(
    X_train,
    y_train,
    epochs=20,
    batch_size=32,
    validation_split=0.2
)
# Out:
# Epoch 1/20
# 2835/2835 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.9607 - loss: 0.1314 - val_accuracy: 0.9639 - val_loss: 0.1159
# Epoch 2/20
# 2835/2835 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.9622 - loss: 0.1215 - val_accuracy: 0.9636 - val_loss: 0.1152
# Epoch 3/20
# 2835/2835 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.9626 - loss: 0.1212 - val_accuracy: 0.9636 - val_loss: 0.1147
# Epoch 4/20
# 2835/2835 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.9626 - loss: 0.1207 - val_accuracy: 0.9641 - val_loss: 0.1155
# Epoch 5/20
# 2835/2835 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9626 - loss: 0.1203 - val_accuracy: 0.9641 - val_loss: 0.1153
# Epoch 6/20
# 2835/2835 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9627 - loss: 0.1202 - val_accuracy: 0.9640 - val_loss: 0.1146
# Epoch 7/20
# 2835/2835 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9627 - loss: 0.1199 - val_accuracy: 0.9641 - val_loss: 0.1150
# Epoch 8/20
# 2835/2835 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9627 - loss: 0.1198 - val_accuracy: 0.9641 - val_loss: 0.1141
# Epoch 9/20
# 2835/2835 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9628 - loss: 0.1198 - val_accuracy: 0.9641 - val_loss: 0.1139
# Epoch 10/20
# 2835/2835 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9628 - loss: 0.1197 - val_accuracy: 0.9640 - val_loss: 0.1139
# Epoch 11/20
# 2835/2835 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9628 - loss: 0.1196 - val_accuracy: 0.9640 - val_loss: 0.1141
# Epoch 12/20
# 2835/2835 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9628 - loss: 0.1196 - val_accuracy: 0.9640 - val_loss: 0.1146
# Epoch 13/20
# 2835/2835 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9628 - loss: 0.1194 - val_accuracy: 0.9640 - val_loss: 0.1144
# Epoch 14/20
# 2835/2835 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9628 - loss: 0.1195 - val_accuracy: 0.9640 - val_loss: 0.1144
# Epoch 15/20
# 2835/2835 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9628 - loss: 0.1194 - val_accuracy: 0.9640 - val_loss: 0.1144
# Epoch 16/20
# 2835/2835 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9628 - loss: 0.1192 - val_accuracy: 0.9640 - val_loss: 0.1140
# Epoch 17/20
# 2835/2835 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9628 - loss: 0.1194 - val_accuracy: 0.9642 - val_loss: 0.1144
# Epoch 18/20
# 2835/2835 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9629 - loss: 0.1192 - val_accuracy: 0.9642 - val_loss: 0.1140
# Epoch 19/20
# 2835/2835 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9628 - loss: 0.1191 - val_accuracy: 0.9640 - val_loss: 0.1143
# Epoch 20/20
# 2835/2835 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9629 - loss: 0.1192 - val_accuracy: 0.9642 - val_loss: 0.1146

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test)

print("Test Accuracy:", test_accuracy)
# Out:
# 394/394 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9636 - loss: 0.1207
# Test Accuracy: 0.9635656476020813

# %%
print(y.unique())
# Out:
# ['normal' 'intrusion']

# %%
# Out:
# ['normal' 'intrusion']

# %%
print(df['attack'].unique())
# Out:
# ['normal' 'intrusion']

# %%
print(y.unique())
# Out:
# ['normal' 'intrusion']
